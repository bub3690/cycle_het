# %%
# registration inference
import torch
import torch.nn as nn
import torch.nn.functional as F
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import Dataset, DataLoader
import cv2


from glob import glob

# %%
# Augmentation with Albumentations
train_transform = A.Compose([
    A.Rotate(limit=25, p=0.8),
    A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=0, p=0.8),
    A.ElasticTransform(alpha=60, sigma=12, p=0.2),
    A.GridDistortion(num_steps=5, distort_limit=0.3, p=0.2),
    A.OpticalDistortion(distort_limit=0.2, shift_limit=0.05, p=0.2),
    A.Resize(512, 512),  # Rescale all images to a fixed size
    ToTensorV2()
])

val_transform = A.Compose([
    A.Resize(512, 512),
    ToTensorV2()
])

class LungSegmentationDataset(Dataset):
    def __init__(self, images, masks, transform=None):
        self.images = images
        self.masks = masks
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = cv2.imread(self.images[idx], cv2.IMREAD_GRAYSCALE)
        mask = cv2.imread(self.masks[idx], cv2.IMREAD_GRAYSCALE)
        file_name = self.images[idx].split('/')[-1]
        
        image = self.transform(image=image)['image'][0]
        mask = self.transform(image=mask)['image'][0]
        
        image = image / 255.0
        mask = mask / 255.0
        
        return image, mask, file_name




mask_datalist = glob('/hdd/project/cylce_het/dataset/ralo_mask/*.jpg')
image_datalist = glob("/hdd/project/cylce_het/dataset/ralo_raw_images/*.jpg")

sorted(mask_datalist), sorted(image_datalist)

# Define dataset and dataloader
train_dataset = LungSegmentationDataset(image_datalist, mask_datalist, transform=val_transform)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)

# Spatial Transformer Network (STN)
class STN(nn.Module):
    def __init__(self, in_shape=(1,512,512), mask_resize: int = 512,
                 dense_neurons=50, freeze_align_model=False):
        super(STN, self).__init__()
        
        assert not in_shape[1] % mask_resize, "The STN size must be a multiple of mask size"
        trainable = not freeze_align_model

        # MaxPooling for input adaptation
        self.pool1 = nn.MaxPool2d(kernel_size=(in_shape[1] // mask_resize, in_shape[2] // mask_resize))

        # Convolutional and pooling layers
        self.pool2 = nn.MaxPool2d(kernel_size=2)
        self.conv1 = nn.Conv2d(in_channels=in_shape[0], out_channels=20, kernel_size=5, stride=1)
        if not trainable:
            self.conv1.requires_grad_(False)

        self.pool3 = nn.MaxPool2d(kernel_size=2)
        self.conv2 = nn.Conv2d(in_channels=20, out_channels=20, kernel_size=5, stride=1)
        if not trainable:
            self.conv2.requires_grad_(False)

        # Flatten layer
        self.flatten = nn.Flatten()

        # Fully connected layers
        self.fc1 = nn.Linear(in_features=self.calculate_flatten_size(in_shape), out_features=dense_neurons)
        if not trainable:
            self.fc1.requires_grad_(False)
        
        self.relu = nn.ReLU()

        # Final alignment layer (6 affine parameters)
        self.fc2 = nn.Linear(in_features=dense_neurons, out_features=6)
        if not trainable:
            self.fc2.requires_grad_(False)
        
        # Initialize the alignment layer to the identity transformation
        self.fc2.weight.data.zero_()
        self.fc2.bias.data.copy_(torch.tensor([1, 0, 0, 0, 1, 0], dtype=torch.float))

    def calculate_flatten_size(self, in_shape):
        # Dummy input to calculate the size after convolution and pooling
        dummy_input = torch.randn(1, in_shape[0], in_shape[1], in_shape[2])
        x = self.pool1(dummy_input)
        x = self.pool2(self.conv1(x))
        x = self.pool3(self.conv2(x))
        return x.numel()

    def forward(self, x):
        # Max Pooling and Convolutional layers
        xs = self.pool1(x)
        xs = self.pool2(self.conv1(xs))
        xs = self.pool3(self.conv2(xs))
        
        # Flatten the feature maps
        xs = self.flatten(xs)

        # Fully connected layers and ReLU
        xs = self.fc1(xs)
        xs = self.relu(xs)
        
        # Output the 6 affine parameters
        theta = self.fc2(xs)
        theta = theta.view(-1, 2, 3)  # Reshape to 2x3 affine matrix
        # Generate affine grid and perform sampling
        grid = F.affine_grid(theta, x.size(), align_corners=False)
        x = F.grid_sample(x, grid, align_corners=False)
        
        return x,grid



# Training loop setup

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
stn_model = STN().to(device)

stn_model.load_state_dict(torch.load('/hdd/project/cylce_het/checkpoint/stn/checkpoint.pth'))

# inference and save all in batch

save_folder = "/hdd/project/cylce_het/dataset/ralo_registered_images/"

stn_model.eval()
with torch.no_grad():
    for idx, (image, mask, file_name) in enumerate(train_loader):
        image = image.to(device,dtype=torch.float)
        mask = mask.to(device,dtype=torch.float)
        image= image.unsqueeze(1)
        mask= mask.unsqueeze(1)
        
        transformed_image, grid = stn_model(mask)
        
        img_res = F.grid_sample(image, grid, align_corners=False)
        
        for i in range(image.size(0)):
            save_path = save_folder + file_name[i]
            # 만약 jpg인 경우 png로 저장
            if save_path.endswith(".jpg"):
                save_path = save_path.replace(".jpg", ".png")
            cv2.imwrite(save_path, img_res[i].squeeze().cpu().numpy()*255)
            print(f"Saved {save_path}")
# Out:
# Using device: cuda
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/809.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1628.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1264.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1009.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2179.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1160.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1437.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2243.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2268.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/8.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/658.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/405.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2225.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2054.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1475.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/409.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1342.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/843.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2072.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/167.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/922.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/476.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/450.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/124.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1659.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/673.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/479.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/163.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/693.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/605.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/118.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/908.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/851.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/805.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/752.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/533.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1741.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1397.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/430.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1738.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/288.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1564.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/732.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1318.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1248.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/159.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/178.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1428.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2318.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/987.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/143.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/209.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1274.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/596.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1460.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2059.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2003.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1719.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/101.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2203.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1889.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1038.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/807.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1734.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2272.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/745.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1832.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1671.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1888.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2209.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/37.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/609.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/136.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1249.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1121.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/239.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/76.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/813.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1422.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/717.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/516.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2007.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/133.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1801.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2104.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1440.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/896.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/675.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/436.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2013.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1903.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1626.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2047.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/150.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/540.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2260.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/362.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1849.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1332.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1666.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/87.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2004.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1781.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/759.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2163.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1273.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/701.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1231.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/107.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2057.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/13.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2340.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/53.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1401.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/974.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/739.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/524.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1055.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2030.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/425.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1191.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/765.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2282.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2126.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/240.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/590.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/11.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2372.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/20.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1921.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2205.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1432.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/70.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1686.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1578.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/795.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/821.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1201.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1414.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1448.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/769.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2313.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/156.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1998.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1349.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/42.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1420.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1026.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1629.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1082.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/823.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2195.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2105.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/120.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1661.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1904.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2266.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1435.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/999.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/512.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1469.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1369.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1314.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/735.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/960.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/166.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2086.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/39.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/866.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/256.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/220.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1717.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1407.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/973.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/122.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1276.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/948.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/827.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2081.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1326.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/536.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1122.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/319.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/467.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/674.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/345.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2302.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1103.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/373.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1375.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1926.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1410.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/35.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1601.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/361.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/797.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1060.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1945.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1887.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/621.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2267.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1573.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/258.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1838.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1511.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/312.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2111.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/847.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/279.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2151.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1508.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1852.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/55.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/127.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/416.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/608.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1654.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1624.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1585.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/369.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1018.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/581.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/228.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1647.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1143.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/862.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1589.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1674.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1226.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2038.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/419.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1663.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2226.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1016.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1101.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1617.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2246.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1705.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/265.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1539.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/738.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1670.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1514.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/154.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1684.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/195.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/432.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1293.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/193.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1395.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2075.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1946.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/317.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1065.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1391.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/471.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1140.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2113.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2016.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1733.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/982.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1994.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2064.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/626.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/683.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/370.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/695.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/578.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1056.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1943.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1762.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/729.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1242.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/295.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2046.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2034.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2295.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/442.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1610.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1811.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/494.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2193.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1641.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1770.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1706.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1396.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/979.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1364.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1177.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/9.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1035.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1812.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1409.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1688.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1546.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1831.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/323.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1365.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1236.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/796.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/310.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2196.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1452.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/509.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2241.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1695.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/721.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1586.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2172.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/422.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1205.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1399.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/722.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1761.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/551.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/523.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/231.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/286.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/196.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1913.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1115.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/859.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1006.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1649.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/704.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1336.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1324.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1084.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/306.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/171.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/650.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/121.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2238.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1614.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1124.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/86.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/750.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1582.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1526.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/836.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1528.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1445.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/806.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/102.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/492.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/328.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2213.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1447.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/235.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/537.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2297.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1251.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1495.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2183.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/994.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1744.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1634.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/741.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1499.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/379.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1769.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/580.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1766.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1965.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1230.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2281.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2137.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1807.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/10.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/584.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/116.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2211.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/917.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2173.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1730.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2035.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1536.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2306.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2053.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2135.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1358.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/747.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1728.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/244.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2076.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1554.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1125.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/918.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/109.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/864.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/734.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/646.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/612.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1804.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1853.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1295.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1477.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/787.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/938.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1689.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2027.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1062.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/142.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1795.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1563.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1939.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/687.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/83.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1938.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/997.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/463.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1538.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/586.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1919.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1436.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/719.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1377.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1785.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/766.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/889.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/839.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1836.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1971.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/686.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1767.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1613.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/281.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2020.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/517.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/763.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/791.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1172.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/877.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1758.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1587.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1534.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/632.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/833.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/684.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/845.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/526.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/300.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1540.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1787.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/157.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2091.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/198.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/958.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/703.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1618.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1405.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2071.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1439.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/637.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/558.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/981.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/665.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1024.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1223.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1072.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/682.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/187.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/798.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/666.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/88.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/901.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/788.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/497.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/457.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/248.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1640.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/140.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1204.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/884.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/339.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/283.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/316.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1381.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1275.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2353.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/110.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1258.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1102.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1085.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2216.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1173.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/366.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/260.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1892.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/270.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1066.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1256.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1040.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1682.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1600.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/47.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1829.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/583.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/334.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/733.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/924.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/804.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1423.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1073.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2139.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/45.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2314.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/135.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1161.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/82.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1715.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1685.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/991.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/431.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1186.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1549.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/716.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1394.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1869.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1108.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/469.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2287.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2351.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/308.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/677.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/67.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2188.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1003.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1870.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2021.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/96.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1092.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1176.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/521.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1630.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1025.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1458.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1392.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/48.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1556.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/251.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1996.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/301.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/597.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1466.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/893.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/3.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1309.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1476.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1557.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/451.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1910.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/606.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/556.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/201.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/950.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/153.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/943.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1071.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/659.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/282.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/569.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2022.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/144.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1479.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/292.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1010.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1799.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/936.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/223.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/113.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/263.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/396.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/711.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1731.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2347.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/360.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1760.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1089.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2125.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1865.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2245.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2248.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2074.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/818.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/224.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1880.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1194.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1959.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1126.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2159.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/417.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/921.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/828.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1901.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1951.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/970.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2107.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1320.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1197.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/374.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2296.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1789.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1983.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/949.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1692.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/401.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/276.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1224.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1331.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/435.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/341.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1823.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/199.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1299.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/975.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1449.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/247.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/842.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/343.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1156.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/520.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1672.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/287.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2171.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1366.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1244.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2237.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/544.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2084.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1917.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2204.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1132.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1063.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/515.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1027.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/456.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/667.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2249.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1822.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/176.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1729.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1105.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1516.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1294.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1246.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1703.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/380.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/80.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1995.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1828.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1896.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/27.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2133.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1190.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2190.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/326.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1952.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1855.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2017.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/727.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1247.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/250.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1118.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2169.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1814.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/309.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1023.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/25.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/575.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2124.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2066.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1726.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1043.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2080.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/437.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/62.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1544.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/912.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/315.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2130.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1323.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2285.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/643.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/627.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1081.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1013.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2094.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1328.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1944.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1784.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1764.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1053.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/129.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2319.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/967.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1885.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/207.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/761.png
# ...
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/212.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1001.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1283.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2070.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2348.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2000.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/342.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1130.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1518.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/126.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/298.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2040.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/714.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1576.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/775.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2067.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2036.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1317.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1879.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2120.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/217.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1702.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1561.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1775.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/390.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2082.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/871.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/895.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/506.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1696.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2148.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2236.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/114.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/835.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2045.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1565.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2370.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/160.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2102.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/628.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2146.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1222.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1988.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/780.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2098.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/688.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1228.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/567.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2283.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/278.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1579.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1321.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1388.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1752.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1456.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1928.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/972.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1777.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2342.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1602.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1905.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1668.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/180.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1625.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/18.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/364.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2367.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/222.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1559.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1531.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2273.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1045.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/445.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/831.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1209.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1135.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1355.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1157.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/730.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/933.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/644.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/64.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2114.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1433.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1940.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1980.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/820.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/579.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/490.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1097.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1054.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2180.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1208.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1319.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/568.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1170.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/898.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/873.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2149.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/814.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/246.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1110.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1515.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/304.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/927.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2101.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/496.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1464.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/33.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1569.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/940.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1142.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/928.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1962.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/359.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/822.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1806.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1187.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/946.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/165.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1028.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2048.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1826.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2182.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1279.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1474.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/639.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/52.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/553.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2058.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/530.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1745.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1621.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/294.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1120.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1302.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/968.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1192.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2001.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1639.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1202.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1979.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/630.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/723.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2187.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2222.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1070.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/885.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/227.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1270.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1697.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/449.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/14.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2063.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/904.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1591.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1300.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1400.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/984.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/307.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/468.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2333.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/888.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1214.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/700.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/841.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/771.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/507.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1507.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1985.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/438.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1310.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2339.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1529.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1281.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1986.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1114.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1182.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2371.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2274.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1593.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1723.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1325.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1562.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1184.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1131.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/252.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1999.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/882.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1268.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/321.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/434.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/532.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/311.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/487.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1645.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/792.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/939.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1434.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2206.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2024.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1285.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2327.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1301.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1778.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1296.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1282.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1575.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/68.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1047.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/988.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/593.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1658.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/500.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2019.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1357.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1872.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2127.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/783.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/527.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/480.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2355.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2360.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2043.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1722.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1441.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1655.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1933.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/746.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/1096.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/911.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/2304.png
# Saved /hdd/project/cylce_het/dataset/ralo_registered_images/870.png
